# %% [markdown]
# # <h1><font color="#f37626">[Lifecycle]</font> autolog-keras 예제 코드
# ----
# `autolog()`는 모델링 과정 중 실험 이력으로 저장하고자 하는 모델을 자동으로 accuinsight+ modeler 콘솔 화면에 기록해주는 메소드 입니다.
#
# - data: IMDB 영화 리뷰
# - keras 사용
#
#
# `autolog()`는 다음의 과정을 통해 실험 이력을 기록합니다.
# 1. 임의의 변수에 `accuinsight()` 할당
# 2. model.fit() 이전에 `autolog()` 선언
# 3. model.fit()을 사용하여 모델 학습 진행
#
# ----

# %% [markdown]
# ### 1. Accuinsight()
# - accuinsight() 객체를 생성합니다.

# %%
from Accuinsight.Lifecycle.keras import accuinsight

accu = accuinsight()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### [option 1] DataCatalog에서 데이터 다운로드
# - DataCatalog에서 관리하는 데이터를 받아올 수 있습니다.
#
#     1. Data catalog 서비스 화면에서 다운로드하려는 데이터의 경로를 __copy location__ 버튼을 클릭하여 복사합니다.
#     2. 복사한 경로를 `get_file()`의 argument로 입력합니다.
#     3. info의 출력값인 데이터가 저장된 경로를 사용하여 데이터를 불러올 수 있습니다.

# %%
dataCatalog_endpoint = 'location'

accu.get_file(dataCatalog_endpoint)

# %% [markdown]
# #### [option 2] Slack 메시지 푸시
# 1. slack api에서 발급받은 token과 메시지를 받아보고자 하는 channel의 id를 입력합니다.
# `set_slack(token, channel_id)`
#
# 2. slack으로 message를 푸시하는 방법은 다음과 같습니다.
#     - 모델 학습 완료시
#     `send_message('your_message')`
#
#     - 학습에 사용되는 metric이 일정 thresholds를 넘은 경우
#     `send_message(thresholds = 0.5)`
#
# > 두 가지 방법을 동시에 사용할 수 없습니다.

# %%
token = 'your_token'
cid = 'your_channel_id'

accu.set_slack(token = token, channel_id = cid)

# %%
# accu.send_message(message = '[DL-classification-keras] 모델 학습 완료')

accu.send_message(thresholds = 0.1)  ### 예제에서는 thresholds를 넘을 경우에만 메시지를 푸시합니다.

# %% [markdown]
# ### 2. Load data
# - __target__
# (긍정: 1 / 부정: 0)

# %%
from keras.datasets import imdb
import numpy as np

# train & test data
(train_data, train_label), (test_data, test_label) = imdb.load_data(num_words=10000)

word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
decoded_review = ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[0]])

X_train = np.zeros((len(train_data), 10000))
for i, sequence in enumerate(train_data):
    X_train[i, sequence] = 1. 
    
X_test = np.zeros((len(train_data), 10000))
for i, sequence in enumerate(test_data):
    X_test[i, sequence] = 1. 


y_train = np.asarray(train_label).astype('float32')
y_test = np.asarray(test_label).astype('float32')


# validation data 
x_val = X_train[:10000]
partial_x_train = X_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# ### 3. Model compile

# %%
from keras.models import Sequential, Model
from keras.layers import Dense
from keras import optimizers
from keras import metrics

def build_basic_model():
    base_model = Sequential()
    base_model.add(Dense(16, activation='relu', input_shape=(10000,)))
    base_model.add(Dense(16, activation='relu'))
    base_model.add(Dense(1, activation='sigmoid'))
    
    return base_model

opt = optimizers.RMSprop(lr=0.0001)
model = build_basic_model()

## model compile
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[metrics.BinaryCrossentropy()])

# %% [markdown]
# ### 4. autolog()
# - `autolog()`에 현재 학습할 모델에 관한 간단한 tag를 입력할 수 있습니다.
# - `autolog()`는 반드시 모델 학습(model.fit()) __이전에__ 호출이 되어야 합니다.

# %%
accu.autolog('Keras-binary-classification')

# %% [markdown]
# ### 5. model fitting

# %%
model.fit(partial_x_train, partial_y_train, epochs=50, batch_size=512, validation_data=(x_val, y_val))
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/50
# 15000/15000 [==============================] - 2s 126us/step - loss: 0.6748 - binary_crossentropy: 0.6748 - val_loss: 0.6529 - val_binary_crossentropy: 0.6529
#
# Epoch 00001: val_binary_crossentropy improved from inf to 0.65293, storing weights.
#
# Epoch 2/50
# 15000/15000 [==============================] - 1s 84us/step - loss: 0.6224 - binary_crossentropy: 0.6224 - val_loss: 0.6033 - val_binary_crossentropy: 0.6033
#
# Epoch 00002: val_binary_crossentropy improved from 0.65293 to 0.60328, storing weights.
#
# Epoch 3/50
# 15000/15000 [==============================] - 1s 84us/step - loss: 0.5666 - binary_crossentropy: 0.5666 - val_loss: 0.5529 - val_binary_crossentropy: 0.5529
#
# Epoch 00003: val_binary_crossentropy improved from 0.60328 to 0.55292, storing weights.
#
# Epoch 4/50
# 15000/15000 [==============================] - 1s 84us/step - loss: 0.5131 - binary_crossentropy: 0.5131 - val_loss: 0.5060 - val_binary_crossentropy: 0.5060
#
# Epoch 00004: val_binary_crossentropy improved from 0.55292 to 0.50605, storing weights.
#
# Epoch 5/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.4648 - binary_crossentropy: 0.4648 - val_loss: 0.4663 - val_binary_crossentropy: 0.4663
#
# Epoch 00005: val_binary_crossentropy improved from 0.50605 to 0.46627, storing weights.
#
# Epoch 6/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.4238 - binary_crossentropy: 0.4238 - val_loss: 0.4330 - val_binary_crossentropy: 0.4330
#
# Epoch 00006: val_binary_crossentropy improved from 0.46627 to 0.43298, storing weights.
#
# Epoch 7/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.3885 - binary_crossentropy: 0.3885 - val_loss: 0.4062 - val_binary_crossentropy: 0.4062
#
# Epoch 00007: val_binary_crossentropy improved from 0.43298 to 0.40624, storing weights.
#
# Epoch 8/50
# 15000/15000 [==============================] - 1s 84us/step - loss: 0.3588 - binary_crossentropy: 0.3588 - val_loss: 0.3836 - val_binary_crossentropy: 0.3836
#
# Epoch 00008: val_binary_crossentropy improved from 0.40624 to 0.38357, storing weights.
#
# Epoch 9/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.3332 - binary_crossentropy: 0.3332 - val_loss: 0.3637 - val_binary_crossentropy: 0.3637
#
# Epoch 00009: val_binary_crossentropy improved from 0.38357 to 0.36371, storing weights.
#
# Epoch 10/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.3111 - binary_crossentropy: 0.3111 - val_loss: 0.3482 - val_binary_crossentropy: 0.3482
#
# Epoch 00010: val_binary_crossentropy improved from 0.36371 to 0.34824, storing weights.
#
# Epoch 11/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.2923 - binary_crossentropy: 0.2923 - val_loss: 0.3352 - val_binary_crossentropy: 0.3352
#
# Epoch 00011: val_binary_crossentropy improved from 0.34824 to 0.33517, storing weights.
#
# Epoch 12/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.2754 - binary_crossentropy: 0.2754 - val_loss: 0.3242 - val_binary_crossentropy: 0.3242
#
# Epoch 00012: val_binary_crossentropy improved from 0.33517 to 0.32417, storing weights.
#
# Epoch 13/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.2606 - binary_crossentropy: 0.2606 - val_loss: 0.3147 - val_binary_crossentropy: 0.3147
#
# Epoch 00013: val_binary_crossentropy improved from 0.32417 to 0.31474, storing weights.
#
# Epoch 14/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.2472 - binary_crossentropy: 0.2472 - val_loss: 0.3067 - val_binary_crossentropy: 0.3067
#
# Epoch 00014: val_binary_crossentropy improved from 0.31474 to 0.30671, storing weights.
#
# Epoch 15/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.2351 - binary_crossentropy: 0.2351 - val_loss: 0.3002 - val_binary_crossentropy: 0.3002
#
# Epoch 00015: val_binary_crossentropy improved from 0.30671 to 0.30018, storing weights.
#
# Epoch 16/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.2242 - binary_crossentropy: 0.2242 - val_loss: 0.2945 - val_binary_crossentropy: 0.2945
#
# Epoch 00016: val_binary_crossentropy improved from 0.30018 to 0.29449, storing weights.
#
# Epoch 17/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.2139 - binary_crossentropy: 0.2139 - val_loss: 0.2898 - val_binary_crossentropy: 0.2898
#
# Epoch 00017: val_binary_crossentropy improved from 0.29449 to 0.28980, storing weights.
#
# Epoch 18/50
# 15000/15000 [==============================] - 1s 81us/step - loss: 0.2045 - binary_crossentropy: 0.2045 - val_loss: 0.2867 - val_binary_crossentropy: 0.2867
#
# Epoch 00018: val_binary_crossentropy improved from 0.28980 to 0.28671, storing weights.
#
# Epoch 19/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.1959 - binary_crossentropy: 0.1959 - val_loss: 0.2841 - val_binary_crossentropy: 0.2841
#
# Epoch 00019: val_binary_crossentropy improved from 0.28671 to 0.28406, storing weights.
#
# Epoch 20/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1879 - binary_crossentropy: 0.1879 - val_loss: 0.2800 - val_binary_crossentropy: 0.2800
#
# Epoch 00020: val_binary_crossentropy improved from 0.28406 to 0.28004, storing weights.
#
# Epoch 21/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1802 - binary_crossentropy: 0.1802 - val_loss: 0.2780 - val_binary_crossentropy: 0.2780
#
# Epoch 00021: val_binary_crossentropy improved from 0.28004 to 0.27802, storing weights.
#
# Epoch 22/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1731 - binary_crossentropy: 0.1731 - val_loss: 0.2767 - val_binary_crossentropy: 0.2767
#
# Epoch 00022: val_binary_crossentropy improved from 0.27802 to 0.27673, storing weights.
#
# Epoch 23/50
# 15000/15000 [==============================] - 1s 81us/step - loss: 0.1664 - binary_crossentropy: 0.1664 - val_loss: 0.2753 - val_binary_crossentropy: 0.2753
#
# Epoch 00023: val_binary_crossentropy improved from 0.27673 to 0.27530, storing weights.
#
# Epoch 24/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1603 - binary_crossentropy: 0.1603 - val_loss: 0.2749 - val_binary_crossentropy: 0.2749
#
# Epoch 00024: val_binary_crossentropy improved from 0.27530 to 0.27493, storing weights.
#
# Epoch 25/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1543 - binary_crossentropy: 0.1543 - val_loss: 0.2740 - val_binary_crossentropy: 0.2740
#
# Epoch 00025: val_binary_crossentropy improved from 0.27493 to 0.27398, storing weights.
#
# Epoch 26/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.1487 - binary_crossentropy: 0.1487 - val_loss: 0.2742 - val_binary_crossentropy: 0.2742
#
# Epoch 00026: val_binary_crossentropy did not improve
#
# Epoch 27/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1433 - binary_crossentropy: 0.1433 - val_loss: 0.2742 - val_binary_crossentropy: 0.2742
#
# Epoch 00027: val_binary_crossentropy did not improve
#
# Epoch 28/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.1382 - binary_crossentropy: 0.1382 - val_loss: 0.2768 - val_binary_crossentropy: 0.2768
#
# Epoch 00028: val_binary_crossentropy did not improve
#
# Epoch 29/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.1333 - binary_crossentropy: 0.1333 - val_loss: 0.2752 - val_binary_crossentropy: 0.2752
#
# Epoch 00029: val_binary_crossentropy did not improve
#
# Epoch 30/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.1286 - binary_crossentropy: 0.1286 - val_loss: 0.2762 - val_binary_crossentropy: 0.2762
#
# Epoch 00030: val_binary_crossentropy did not improve
#
# Epoch 31/50
# 15000/15000 [==============================] - 2s 157us/step - loss: 0.1240 - binary_crossentropy: 0.1240 - val_loss: 0.2773 - val_binary_crossentropy: 0.2773
#
# Epoch 00031: val_binary_crossentropy did not improve
#
# Epoch 32/50
# 15000/15000 [==============================] - 3s 176us/step - loss: 0.1197 - binary_crossentropy: 0.1197 - val_loss: 0.2788 - val_binary_crossentropy: 0.2788
#
# Epoch 00032: val_binary_crossentropy did not improve
#
# Epoch 33/50
# 15000/15000 [==============================] - 2s 115us/step - loss: 0.1156 - binary_crossentropy: 0.1156 - val_loss: 0.2802 - val_binary_crossentropy: 0.2802
#
# Epoch 00033: val_binary_crossentropy did not improve
#
# Epoch 34/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1115 - binary_crossentropy: 0.1115 - val_loss: 0.2819 - val_binary_crossentropy: 0.2819
#
# Epoch 00034: val_binary_crossentropy did not improve
#
# Epoch 35/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1077 - binary_crossentropy: 0.1077 - val_loss: 0.2840 - val_binary_crossentropy: 0.2840
#
# Epoch 00035: val_binary_crossentropy did not improve
#
# Epoch 36/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.1040 - binary_crossentropy: 0.1040 - val_loss: 0.2859 - val_binary_crossentropy: 0.2859
#
# Epoch 00036: val_binary_crossentropy did not improve
#
# Epoch 37/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.1003 - binary_crossentropy: 0.1003 - val_loss: 0.2883 - val_binary_crossentropy: 0.2883
#
# Epoch 00037: val_binary_crossentropy did not improve
#
# Epoch 38/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.0969 - binary_crossentropy: 0.0969 - val_loss: 0.2905 - val_binary_crossentropy: 0.2905
#
# Epoch 00038: val_binary_crossentropy did not improve
#
# Epoch 39/50
# 15000/15000 [==============================] - 1s 85us/step - loss: 0.0935 - binary_crossentropy: 0.0935 - val_loss: 0.2931 - val_binary_crossentropy: 0.2931
#
# Epoch 00039: val_binary_crossentropy did not improve
#
# Epoch 40/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0903 - binary_crossentropy: 0.0903 - val_loss: 0.2964 - val_binary_crossentropy: 0.2964
#
# Epoch 00040: val_binary_crossentropy did not improve
#
# Epoch 41/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0871 - binary_crossentropy: 0.0871 - val_loss: 0.2991 - val_binary_crossentropy: 0.2991
#
# Epoch 00041: val_binary_crossentropy did not improve
#
# Epoch 42/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0841 - binary_crossentropy: 0.0841 - val_loss: 0.3020 - val_binary_crossentropy: 0.3020
#
# Epoch 00042: val_binary_crossentropy did not improve
#
# Epoch 43/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0813 - binary_crossentropy: 0.0813 - val_loss: 0.3065 - val_binary_crossentropy: 0.3065
#
# Epoch 00043: val_binary_crossentropy did not improve
#
# Epoch 44/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0785 - binary_crossentropy: 0.0785 - val_loss: 0.3076 - val_binary_crossentropy: 0.3076
#
# Epoch 00044: val_binary_crossentropy did not improve
#
# Epoch 45/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0756 - binary_crossentropy: 0.0756 - val_loss: 0.3121 - val_binary_crossentropy: 0.3121
#
# Epoch 00045: val_binary_crossentropy did not improve
#
# Epoch 46/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0729 - binary_crossentropy: 0.0729 - val_loss: 0.3153 - val_binary_crossentropy: 0.3153
#
# Epoch 00046: val_binary_crossentropy did not improve
#
# Epoch 47/50
# 15000/15000 [==============================] - 1s 86us/step - loss: 0.0703 - binary_crossentropy: 0.0703 - val_loss: 0.3182 - val_binary_crossentropy: 0.3182
#
# Epoch 00047: val_binary_crossentropy did not improve
#
# Epoch 48/50
# 15000/15000 [==============================] - 1s 83us/step - loss: 0.0678 - binary_crossentropy: 0.0678 - val_loss: 0.3218 - val_binary_crossentropy: 0.3218
#
# Epoch 00048: val_binary_crossentropy did not improve
#
# Epoch 49/50
# 15000/15000 [==============================] - 1s 82us/step - loss: 0.0654 - binary_crossentropy: 0.0654 - val_loss: 0.3271 - val_binary_crossentropy: 0.3271
#
# Epoch 00049: val_binary_crossentropy did not improve
#
# Epoch 50/50
# 15000/15000 [==============================] - 1s 85us/step - loss: 0.0630 - binary_crossentropy: 0.0630 - val_loss: 0.3291 - val_binary_crossentropy: 0.3291
#
# Epoch 00050: val_binary_crossentropy did not improve
#
# Using epoch 00025 with val_binary_crossentropy: 0.27398

# %% [markdown]
# __모델 학습이 완료되면 `autolog()`는 자동으로 해제됩니다.__
# 따라서 모델 학습 이력을 추가하고자 할 경우, 다시 한 번 `autolog()` 호출 후 모델 훈련을 진행해야 합니다.

# %% [markdown]
# ### 6. 저장된 모델 불러오기
# - `autolog()`를 사용하여 모델의 학습 이력을 Lifecycle에 기록할 경우, 자동으로 훈련 도중 가장 좋은 metric을 기록한 epoch에서의 모델 가중치가 저장됩니다.
# - 따라서 저장된 모델을 불러와 공동 작업자들과 모델을 공유하거나, 모델 재학습을 수행할 수 있습니다.
#
#     1. Accuinsight+ workspace list 혹은 해당 모델의 상세화면으로 접속하여 _Experiment_ 중 불러오고자 하는 모델의 __Run name__을 복사합니다.
#     2. ___utils___에서 `load_model()` 함수를 호출하여 모델을 불러올 수 있습니다.

# %%
from Accuinsight.Lifecycle.utils import load_model

saved_model = load_model('keras-A9E821A55D5F4CA9A78D86827C62AA62_13')

# %%
saved_model.get_weights()
# Out:
# [array([[-0.02157974,  0.01793922, -0.00658817, ...,  0.01585907,
#           0.00722466,  0.02340497],
#         [ 0.01130816,  0.02808222, -0.00071141, ..., -0.01401629,
#          -0.01594194,  0.00995289],
#         [-0.01384417,  0.01335631,  0.01874032, ...,  0.00270803,
#           0.00705006,  0.03091275],
#         ...,
#         [-0.02350396, -0.0181123 , -0.0004642 , ..., -0.01544702,
#           0.00950608,  0.00926542],
#         [ 0.01578502, -0.01753234,  0.00388583, ..., -0.0154772 ,
#           0.01169709,  0.00266412],
#         [ 0.01752615, -0.0051559 ,  0.01353151, ...,  0.01527549,
#           0.00647289,  0.02042266]], dtype=float32),
#  array([ 0.00769699,  0.00435105,  0.00520558,  0.0025067 ,  0.00225739,
#         -0.00069461,  0.00018096,  0.00558622,  0.00441365,  0.00477135,
#          0.00354772,  0.01000588,  0.00634174,  0.00376313,  0.00469057,
#          0.00822093], dtype=float32),
#  array([[-1.66987658e-01, -3.34941030e-01,  2.75082707e-01,
#           3.62039864e-01,  3.77821684e-01,  3.90422970e-01,
#          -9.45006236e-02,  2.53930300e-01, -3.72809649e-01,
#           3.30799699e-01,  2.16861311e-02,  2.01453984e-01,
#          -4.06499118e-01,  1.52057726e-02, -1.80755511e-01,
#           3.92436445e-01],
#         [ 3.91900271e-01, -9.40801352e-02,  3.20963979e-01,
#          -3.79561067e-01, -2.56974310e-01, -3.34927768e-01,
#          -2.67592430e-01, -1.43154472e-01, -1.76023290e-01,
#           3.25460106e-01,  1.63965285e-01, -1.15376331e-01,
#          -3.37838888e-01,  4.59005684e-02, -1.96312685e-02,
#           2.59019285e-01],
#         [-2.11532578e-01,  3.84716243e-01, -2.28495777e-01,
#          -3.37844431e-01,  2.07990259e-01, -4.37366068e-02,
#          -3.11415136e-01, -2.54894793e-01,  1.41484747e-02,
#           1.19775459e-01,  1.90230846e-01, -2.63758659e-01,
#           1.47413507e-01, -3.51178974e-01, -3.28437895e-01,
#           8.46693572e-03],
#         [-2.68225640e-01, -4.20730799e-01, -3.52864325e-01,
#           3.99742067e-01,  2.92168468e-01, -3.39842498e-01,
#          -2.23657474e-01, -4.16474670e-01, -1.79117933e-01,
#           3.75809371e-01,  8.80485624e-02, -2.49394417e-01,
#           3.97813646e-03, -3.48902732e-01, -6.09355383e-02,
#           3.50007057e-01],
#         [-3.23493868e-01,  2.58524746e-01, -1.54341131e-01,
#          -1.70233056e-01,  2.85766840e-01,  2.74099112e-01,
#          -3.02223891e-01,  4.10516381e-01, -4.07301426e-01,
#          -4.68087569e-02, -3.39323968e-01,  1.29910782e-01,
#          -1.92189053e-01, -3.34616095e-01, -2.97564089e-01,
#          -1.96214318e-02],
#         [ 3.55867803e-01,  1.90772161e-01,  1.84470356e-01,
#          -2.86710536e-04,  8.22907463e-02, -3.70609641e-01,
#           7.88176358e-02, -3.65979075e-01, -6.54382557e-02,
#          -3.05941731e-01, -1.90208286e-01, -1.37174457e-01,
#           3.44356865e-01,  2.75245994e-01, -2.50604391e-01,
#          -2.80821949e-01],
#         [ 2.74203926e-01, -9.25756767e-02,  3.76334667e-01,
#           3.22750062e-01, -2.75194585e-01, -1.69761389e-01,
#          -2.41100058e-01, -5.99417835e-02, -5.04434668e-03,
#          -1.81098238e-01, -1.64339244e-01, -4.17412639e-01,
#           1.49037510e-01, -3.01922858e-01,  6.44244701e-02,
#           2.60787278e-01],
#         [-2.32597664e-01,  2.99433380e-01,  3.14494967e-01,
#           9.57005098e-02, -3.35698783e-01, -4.11195308e-01,
#           2.71426022e-01, -4.17849988e-01,  2.01530769e-01,
#           3.00775975e-01,  9.64671969e-02,  4.16213244e-01,
#          -1.69708952e-01,  8.32110569e-02, -4.10409480e-01,
#           1.03182867e-01],
#         [-3.02728266e-01,  8.51843432e-02,  4.35824841e-01,
#           2.83127397e-01,  2.11641148e-01,  2.71384239e-01,
#           3.41335058e-01, -4.04004723e-01,  2.78646797e-01,
#           4.89166826e-02,  2.99951464e-01,  4.03141052e-01,
#          -2.38244068e-02, -4.03916419e-01,  3.06459934e-01,
#           2.76821852e-02],
#         [ 1.87369287e-01,  2.42698610e-01, -1.90258518e-01,
#           2.71422595e-01, -6.57816455e-02, -1.12511493e-01,
#          -2.37224281e-01, -4.14312392e-01, -2.63577789e-01,
#          -9.98546183e-02, -2.43819118e-01, -1.39483511e-01,
#           4.86253947e-03, -4.10362899e-01,  3.37374181e-01,
#          -1.32827818e-01],
#         [-3.43863517e-02,  2.59501245e-02, -3.66941420e-03,
#          -3.20676751e-02,  2.53432766e-02,  1.57260895e-01,
#          -3.04387718e-01,  6.31589964e-02,  1.08055234e-01,
#           2.74045616e-01, -9.05569419e-02, -2.48170495e-01,
#          -3.86205733e-01, -1.99498773e-01, -9.55689028e-02,
#           2.76430875e-01],
#         [ 2.39054963e-01,  9.79666412e-02,  7.89690986e-02,
#          -1.81057215e-01, -4.09564972e-01,  1.50050282e-01,
#          -3.93757433e-01,  1.79354429e-01, -1.01293296e-01,
#           4.04506773e-01,  3.55339646e-01, -2.45696098e-01,
#           1.89837694e-01, -5.43620028e-02,  1.81858227e-01,
#          -1.42906941e-02],
#         [-8.26840624e-02,  2.84881406e-02, -4.17325020e-01,
#           8.38978589e-02,  2.20651910e-01,  2.84505457e-01,
#           2.15932056e-01, -1.83080763e-01, -1.74353167e-01,
#          -2.54919767e-01,  4.15282965e-01, -2.80479379e-02,
#           2.95063823e-01,  2.77860820e-01, -2.76867747e-01,
#           4.24514920e-01],
#         [ 2.64162272e-01, -3.17262292e-01,  1.50789395e-01,
#          -2.35052884e-01, -1.14783756e-01, -2.17395723e-01,
#          -2.88444549e-01, -2.10651085e-01, -2.16363773e-01,
#          -2.15007737e-01,  1.89353600e-01, -2.38952056e-01,
#           4.33422238e-01,  2.16084421e-01, -7.98698049e-04,
#          -1.38880149e-01],
#         [ 2.08340079e-01,  1.23949185e-01, -2.09101468e-01,
#          -3.26189160e-01,  4.11453605e-01, -2.46287778e-01,
#           1.19140983e-01,  1.54755995e-01,  3.61552536e-01,
#           2.97894418e-01,  2.04952657e-01, -1.06319003e-02,
#          -1.00968778e-02,  5.13284421e-03, -3.85384858e-01,
#           3.13198626e-01],
#         [-2.04817072e-01,  3.43293577e-01,  1.73103243e-01,
#          -1.43844178e-02,  3.45121592e-01,  1.66477367e-01,
#           3.48569751e-01, -3.52365524e-02,  4.08816218e-01,
#           4.06563934e-03, -3.25432569e-01,  4.02546018e-01,
#           3.92753482e-01,  4.04901385e-01, -2.78901190e-01,
#          -2.94578791e-01]], dtype=float32),
#  array([ 0.00706861,  0.00871443,  0.00160854, -0.00808557, -0.00064133,
#          0.00810858,  0.00883471,  0.00059873, -0.0084689 ,  0.00864716,
#          0.00683812,  0.00806818,  0.00549925,  0.00907622, -0.00094708,
#         -0.00690202], dtype=float32),
#  array([[-0.0831805 ],
#         [-0.19909285],
#         [ 0.5922516 ],
#         [-0.18768582],
#         [ 0.1378548 ],
#         [ 0.5964022 ],
#         [ 0.2276456 ],
#         [ 0.18892108],
#         [ 0.4761265 ],
#         [-0.57934463],
#         [-0.1531684 ],
#         [ 0.14063534],
#         [ 0.33791304],
#         [ 0.27679503],
#         [ 0.36695558],
#         [ 0.3356146 ]], dtype=float32),
#  array([-0.00613165], dtype=float32)]
